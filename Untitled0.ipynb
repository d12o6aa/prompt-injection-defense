# %%
# !pip install transformers sentencepiece pandas pyarrow

import pandas as pd
from transformers import pipeline

translator = pipeline(
    "translation",
    model="facebook/nllb-200-distilled-600M"
)
# Out:
# ...
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Device set to use cuda:0
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[2], line 6
#       3 import pandas as pd
#       4 from transformers import pipeline
# ----> 6 translator = pipeline(
#       7     "translation",
#       8     model="facebook/nllb-200-distilled-600M"
#       9 )
#
# File ~/miniconda3/lib/python3.13/site-packages/transformers/pipelines/__init__.py:1229, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, processor, framework, revision, use_fast, token, device, device_map, dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#    1226 if processor is not None:
#    1227     kwargs["processor"] = processor
# -> 1229 return pipeline_class(model=model, framework=framework, task=task, **kwargs)
#
# ...

# %%
df = pd.read_parquet('/data/test-00000-of-00001.parquet', engine="pyarrow")

# %%
def translate_to_egyptian(text):
    fusha = translator(text, src_lang="eng_Latn", tgt_lang="arb_Arab", max_length=2000)[0]['translation_text']
    prompt = f"حوّل هذه الجملة من العربية الفصحى إلى اللهجة المصرية: {fusha}"
    egy = translator(prompt, src_lang="arb_Arab", tgt_lang="arb_Arab", max_length=2000)[0]['translation_text']
    return egy

translated = []
for p in df['text']:
    try:
        translated.append(translate_to_egyptian(p))
    except Exception as e:
        print("Error:", e)
        translated.append(p)

df["egyptian_prompt"] = translated
df.to_parquet("translated_egyptian.parquet", index=False)

# from google.colab import files
# files.download("translated_egyptian.parquet")
