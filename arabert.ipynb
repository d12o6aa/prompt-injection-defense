# %%
pip install arabert
# Out:
# Collecting arabert
#   Downloading arabert-1.0.1-py3-none-any.whl.metadata (16 kB)
# Collecting PyArabic (from arabert)
#   Downloading PyArabic-0.6.15-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: farasapy in /home/doaa/miniconda3/lib/python3.13/site-packages (from arabert) (0.1.1)
# Collecting emoji==1.4.2 (from arabert)
#   Downloading emoji-1.4.2.tar.gz (184 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests~=2.32 in /home/doaa/miniconda3/lib/python3.13/site-packages (from farasapy->arabert) (2.32.3)
# Requirement already satisfied: tqdm~=4.66 in /home/doaa/miniconda3/lib/python3.13/site-packages (from farasapy->arabert) (4.67.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/doaa/miniconda3/lib/python3.13/site-packages (from requests~=2.32->farasapy->arabert) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/doaa/miniconda3/lib/python3.13/site-packages (from requests~=2.32->farasapy->arabert) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/doaa/miniconda3/lib/python3.13/site-packages (from requests~=2.32->farasapy->arabert) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/doaa/miniconda3/lib/python3.13/site-packages (from requests~=2.32->farasapy->arabert) (2025.4.26)
# Requirement already satisfied: six>=1.14.0 in /home/doaa/miniconda3/lib/python3.13/site-packages (from PyArabic->arabert) (1.17.0)
# Downloading arabert-1.0.1-py3-none-any.whl (179 kB)
# Downloading PyArabic-0.6.15-py3-none-any.whl (126 kB)
# Building wheels for collected packages: emoji
#   DEPRECATION: Building 'emoji' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'emoji'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-1.4.2-py3-none-any.whl size=186540 sha256=dce7c4aa1b8b567fb89cf009424b697f96df83655bc427ec993a80a180d2919d
#   Stored in directory: /home/doaa/.cache/pip/wheels/e1/79/2a/9864bac03173079abcc089d3eb3ec87456ac09c381b801f1a3
# Successfully built emoji
# Installing collected packages: emoji, PyArabic, arabert
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [arabert]m2/3 [arabert]
# Successfully installed PyArabic-0.6.15 arabert-1.0.1 emoji-1.4.2
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from arabert.preprocess import ArabertPreprocessor

model_name="aubmindlab/bert-large-arabertv2"
arabert_prep = ArabertPreprocessor(model_name=model_name)

text = "ولن نبالغ إذا قلنا إن هاتف أو كمبيوتر المكتب في زمننا هذا ضروري"
arabert_prep.preprocess(text)
# Out:
# /home/doaa/miniconda3/lib/python3.13/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'farasa-api.qcri.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 100%|██████████| 241M/241M [12:42<00:00, 316kiB/s]
# [2025-11-11 20:18:29,034 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# 'و+ لن نبالغ إذا قل +نا إن هاتف أو كمبيوتر ال+ مكتب في زمن +نا هذا ضروري'
